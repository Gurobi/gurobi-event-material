# %% [markdown]
# # Gurobi aviation challenge

# %%
import pandas as pd

# %%
data = pd.read_excel('data.xlsx', sheet_name='Flights')
data
# Out:
#    Flight From To  Departure  Arrival Departure.1  Arrival  Route Aircraft  \
# 0   GRB01    A  B          4        7    09:00:00  10:30:00    AB       A1
# 1   GRB02    A  D         13       15    13:30:00  14:30:00    AD       A2
# 2   GRB03    A  C         14       20    14:00:00  17:00:00    AC       A4
# 3   GRB04    A  B         15       18    14:30:00  16:00:00    AB       A3
# 4   GRB05    B  C          1        6    07:30:00  10:00:00    BC       A2
# 5   GRB06    B  D          7       13    10:30:00  13:30:00    BD       A1
# 6   GRB07    B  A          8       11    11:00:00  12:30:00    AB       A4
# 7   GRB08    B  D         19       25    16:30:00  19:30:00    BD       A3
# 8   GRB09    B  C         21       26    17:30:00  20:00:00    BC       A1
# 9   GRB10    C  B          1        6    07:30:00  10:00:00    BC       A4
# 10  GRB11    C  A          6       12    10:00:00  13:00:00    AC       A2
# ...
